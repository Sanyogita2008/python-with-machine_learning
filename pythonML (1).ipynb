# %%
print("hello python")
a=input("enter the value ")
print(a                                                                                                                                                         )
# Out:
# hello python
# enter the value 10
# 10

# %%
print("hello python")
a=input("enter the value")
print(a)
# Out:
# hello python
# enter the value18
# 18

# %%
a=input("enter the value ")
b=int(a)
print(type(b))
# Out:
# enter the value 30
# <class 'int'>

# %%
num_str="10"
num_int=int(num_str)
print(num_int)
# Out:
# 10

# %%
num_str="10"
num_int=int(num_str)
print(type(num_int))
# Out:
# <class 'int'>

# %%
num_str="10"
num_int=int(num_str)
print(type(num_str))
print(type(num_int))
# Out:
# <class 'str'>
# <class 'int'>

# %%
demo="hello python"
print("demo")
# Out:
# demo

# %%
demo=" hello python"
print(demo*3)
# Out:
#  hello python hello python hello python

# %%
a="10"
b="20"
print(a+b)
# Out:
# 1020

# %%
a= "sagar and abhi are good boy"
print(a[10:14])
# Out:
# abhi

# %%
a= "sagar and abhi are good boy"
print(a[0:])
print(a[:-1])
print(a[-1])
# Out:
# sagar and abhi are good boy
# sagar and abhi are good bo
# y

# %%
x="manthesh is bad boy"
print(len(x))
# Out:
# 19
