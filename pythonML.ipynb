# %%
print("hello python")
a=input("enter the value ")
print(a                                                                                                                                                         )
# Out:
# hello python
# enter the value 10
# 10

# %%
print("hello python")
a=input("enter the value")
print(a)
# Out:
# hello python
# enter the value18
# 18

# %%
a=input("enter the value ")
b=int(a)
print(type(b))
# Out:
# enter the value 30
# <class 'int'>
